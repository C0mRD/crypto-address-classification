# %%
# import necessary libraries
import pandas as pd

# %%
# Load All 3 dataset - bitcoin, ethereum, dash
btc_df = pd.read_csv("../dataset/exp1_bitcoin_addr.csv")
eth_df = pd.read_csv("../dataset/exp2_ethereum_addr.csv")
dash_df = pd.read_csv("../dataset/blockchair_dash_addresses_latest.tsv", delimiter='\t')

# %%
btc_df.head()
# Out:
#                               address category  active_days_1y  \
# 0  1GVTTTRgnye1saBqx39FWXaei2LftDBZTh      cex             145
# 1  1GtYgNXsAahtFXobSTWKDxQnx1zrSP1Efz      cex              14
# 2  1A67n3kTTGcuGxskLYRUyo7vvrrgRutvup      cex              11
# 3  1AF9EPcL6ECXWdAgoPjzHVQyyG2nGJxdrZ      cex               6
# 4  1NRpjhdJsR3cFKiFiQ38sH1jLubcaxGZua      cex               4
#
#    active_days_180d  active_days_30d  day_r_1y  day_r_180d  day_r_30d  \
# 0                 0                0       139           0          0
# 1                 0                0        12           0          0
# 2                 0                0         9           0          0
# 3                 0                0         5           0          0
# 4                 0                0         1           0          0
#
#    day_s_1y  day_s_180d  ...  var_cnt_s_30d  var_opns_1y  var_opns_180d  \
# 0         6           0  ...            NaN    43.941379            NaN
# 1        12           0  ...            NaN     1.104396            NaN
# 2         2           0  ...            NaN    13.563636            NaN
# 3         5           0  ...            NaN     0.700000            NaN
# 4         3           0  ...            NaN     1.000000            NaN
#
#    var_opns_30d  var_opns_r_1y  var_opns_r_180d  var_opns_r_30d  \
# 0           NaN       0.054789              NaN             NaN
# 1           NaN       0.439560              NaN             NaN
# 2           NaN      23.072727              NaN             NaN
# 3           NaN       0.166667              NaN             NaN
# 4           NaN       2.250000              NaN             NaN
#
#    var_opns_s_1y  var_opns_s_180d  var_opns_s_30d
# 0      45.399234              NaN             NaN
# 1       0.708791              NaN             NaN
# 2       2.454545              NaN             NaN
# 3       0.666667              NaN             NaN
# 4       0.250000              NaN             NaN
#
# [5 rows x 146 columns]

# %%
eth_df.head()
# Out:
#                                       address category  active_days_1y  \
# 0  0xc979a855f821c87c294ccdd164582c6d134eeb09   wallet              12
# 1  0xec70b00ea9f89fd8d110951b78ae707031af05f1   wallet              14
# 2  0xe62b8006fc86d098d8724d35c25ef43307a7ea0c      cex              13
# 3  0x4dbb85a7550271f5e9ea21acc16b0d1acccbfdba   wallet              13
# 4  0xfbc9e24f8259a3c1c3d0eae9113f73b08838546e      cex              23
#
#    opns_1y  calls_1y  cnt_1y        amt_1y  day_ns_1y  opn_ns_1y  amt_ns_1y  \
# 0       20         9      37  1.567982e+04        8.0        3.0   0.097444
# 1       19         8      46  1.221674e+04       11.0        8.0   0.414996
# 2        7         2      32  1.500235e+03       13.0        4.0   0.116631
# 3       17         7      32  2.402251e+06        8.0        7.0   0.509901
# 4        8         1      35  1.079699e+01       14.0        1.0   5.397157
#
#    ...  mean_cnt_cr_30d  var_cnt_cr_30d  max_opn_cr_30d  min_opn_cr_30d  \
# 0  ...              NaN             NaN             NaN             NaN
# 1  ...              NaN             NaN             NaN             NaN
# 2  ...              NaN             NaN             NaN             NaN
# 3  ...              NaN             NaN             NaN             NaN
# 4  ...              NaN             NaN             NaN             NaN
#
#    mean_opn_cr_30d  var_opn_cr_30d  max_cal_cr_30d  min_cal_cr_30d  \
# 0              NaN             NaN             NaN             NaN
# 1              NaN             NaN             NaN             NaN
# 2              NaN             NaN             NaN             NaN
# 3              NaN             NaN             NaN             NaN
# 4              NaN             NaN             NaN             NaN
#
#    mean_cal_cr_30d  var_cal_cr_30d
# 0              NaN             NaN
# 1              NaN             NaN
# 2              NaN             NaN
# 3              NaN             NaN
# 4              NaN             NaN
#
# [5 rows x 209 columns]

# %%
dash_df.head()
# Out:
#                               address         balance
# 0  XmZQkfLtk3xLtbBMenTdaZMxsUBYAsRz1o  42753092146319
# 1  XdAUmwtig27HBG6WfYyHAzP8n6XC9jESEw  42266423923088
# 2  XnT33zjrFKjt3ymfyQZs2FPiKNer3WVj14  20318403315756
# 3  XkprrJjsXsPGjboBoFsJAE7HeFXn96QFzZ  12061181201722
# 4  XmJBF1DaZNWruKWSodMyS56wBf2afTq5y9  11530009910072

# %%
# Drop any duplicate values
btc_df.drop_duplicates(inplace=True)
eth_df.drop_duplicates(inplace=True)
dash_df.drop_duplicates(inplace=True)

# %%
# Take only necessary columns
btc_df = btc_df[['address']].copy()
eth_df = eth_df[['address']].copy()
dash_df = dash_df[['address']].copy()

# %%
btc_df.head()
# Out:
#                               address
# 0  1GVTTTRgnye1saBqx39FWXaei2LftDBZTh
# 1  1GtYgNXsAahtFXobSTWKDxQnx1zrSP1Efz
# 2  1A67n3kTTGcuGxskLYRUyo7vvrrgRutvup
# 3  1AF9EPcL6ECXWdAgoPjzHVQyyG2nGJxdrZ
# 4  1NRpjhdJsR3cFKiFiQ38sH1jLubcaxGZua

# %%
# Print the Shape to check for class imbalance
btc_df.shape
# Out:
# (1569520, 1)

# %%
eth_df.shape
# Out:
# (1000000, 1)

# %%
dash_df.shape
# Out:
# (1569520, 1)

# %%
# check if there is null values
btc_df.isnull().sum()
# Out:
# address    0
# dtype: int64

# %%
eth_df.isnull().sum()
# Out:
# address    0
# dtype: int64

# %%
dash_df.isnull().sum()
# Out:
# address    0
# dtype: int64

# %%
# Add a new column type to act as label
btc_df["type"] = "bitcoin"

# %%
btc_df.head()
# Out:
#                               address     type
# 0  1GVTTTRgnye1saBqx39FWXaei2LftDBZTh  bitcoin
# 1  1GtYgNXsAahtFXobSTWKDxQnx1zrSP1Efz  bitcoin
# 2  1A67n3kTTGcuGxskLYRUyo7vvrrgRutvup  bitcoin
# 3  1AF9EPcL6ECXWdAgoPjzHVQyyG2nGJxdrZ  bitcoin
# 4  1NRpjhdJsR3cFKiFiQ38sH1jLubcaxGZua  bitcoin

# %%
eth_df['type'] = 'ethereum'
dash_df['type'] = 'dash'

# %%
# Concatenate all dataset to one
crypto_df = pd.concat([btc_df, eth_df, dash_df])

# %%
crypto_df
# Out:
#                                     address     type
# 0        1GVTTTRgnye1saBqx39FWXaei2LftDBZTh  bitcoin
# 1        1GtYgNXsAahtFXobSTWKDxQnx1zrSP1Efz  bitcoin
# 2        1A67n3kTTGcuGxskLYRUyo7vvrrgRutvup  bitcoin
# 3        1AF9EPcL6ECXWdAgoPjzHVQyyG2nGJxdrZ  bitcoin
# 4        1NRpjhdJsR3cFKiFiQ38sH1jLubcaxGZua  bitcoin
# ...                                     ...      ...
# 1569515  XmdBpSoS5k6pECqz8FX1c1PT9L3tvrtNhP     dash
# 1569516  XaySCtccCqCucwCpBpm69URFZ56pd1XsCC     dash
# 1569517  XqqdWm1Xvyfs8yDujaoi1uMWgumM1in9zz     dash
# 1569518  XbmSdSDhmoxJ6RRHWZtivqePEyHiwryFLg     dash
# 1569519  XmNePjS6tWfcKxgsS2JHA6KcJay9XQcQ7H     dash
#
# [3350566 rows x 2 columns]

# %%
# Shuffle the dataframe in random order
new_crypto_df = crypto_df.sample(frac=1).reset_index(drop=True).copy()

# %%
new_crypto_df
# Out:
#                                             address      type
# 0                XhuhEPkeVbi7gTwiAU2jfNmSCSkbmGiwN1      dash
# 1                Xu3NW9doqxLJiUhpAEVgWAZA82N2HTfaV4      dash
# 2        0x756198ecf2274e8134417a326b156e93ac6280b5  ethereum
# 3        0x806b72e8088dc4b20f3ea9913161973aa3f6263f  ethereum
# 4                19uYGTAS64UWgmn2UhjJmFP4SmNs85ezHW   bitcoin
# ...                                             ...       ...
# 3350561          XkhpNHmSLevhTYi1nc2ENph5RHWaaSvsA5      dash
# 3350562          XtjEA9BUwZj1mQnE1rnAf9vLiV2ne5BPZg      dash
# 3350563          3MAMG4PXqorrxTAXpt1N3hxFcgptxEtyMi   bitcoin
# 3350564          XuZwcw6735XqooUgQ5aezEx6tKGjcZ6141      dash
# 3350565          1FntmstRUDVHko2EQP8op4BnVAukdf2Uof   bitcoin
#
# [3350566 rows x 2 columns]

# %%
new_crypto_df.to_csv("preprocessed_dataset.csv", index=False)
